# %%
import nselib
from nselib import capital_market

# %%
nselib.trading_holiday_calendar()
# Out:
#                                    Product  tradingDate    weekDay  \
# 0                          Corporate Bonds  22-Jan-2024     Monday
# 1                          Corporate Bonds  26-Jan-2024     Friday
# 2                          Corporate Bonds  19-Feb-2024     Monday
# 3                          Corporate Bonds  08-Mar-2024     Friday
# 4                          Corporate Bonds  25-Mar-2024     Monday
# ..                                     ...          ...        ...
# 15  Securities Lending & Borrowing Schemes  12-Oct-2024   Saturday
# 16  Securities Lending & Borrowing Schemes  01-Nov-2024     Friday
# 17  Securities Lending & Borrowing Schemes  02-Nov-2024   Saturday
# 18  Securities Lending & Borrowing Schemes  15-Nov-2024     Friday
# 19  Securities Lending & Borrowing Schemes  25-Dec-2024  Wednesday
#
#                              description Sr_no
# 0                      Special Holiday\r     1
# 1                         Republic Day\r     2
# ...

# %%
capital_market.bhav_copy_equities(trade_date='3-4-2024')
# Out:
#           SYMBOL SERIES     OPEN     HIGH      LOW    CLOSE     LAST  \
# 0     1018GS2026     GS   109.50   111.00   109.50   111.00   111.00
# 1     182D010824     TB    97.00    97.55    97.00    97.55    97.55
# 2     182D050924     TB    96.80    96.80    96.80    96.80    96.80
# 3     182D060624     TB    98.52    98.52    98.52    98.52    98.52
# 4     182D080824     TB    97.21    97.21    97.21    97.21    97.21
# ...          ...    ...      ...      ...      ...      ...      ...
# 2726        ZOTA     EQ   497.55   510.00   492.60   501.95   499.00
# 2727       ZUARI     EQ   192.00   200.25   191.30   198.50   198.50
# 2728    ZUARIIND     EQ   333.00   349.00   332.95   346.45   348.00
# 2729   ZYDUSLIFE     EQ   997.00   999.50   981.20   987.70   984.65
# 2730   ZYDUSWELL     EQ  1502.00  1559.85  1500.00  1550.45  1545.00
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL    TIMESTAMP  TOTALTRADES
# 0        111.00       7107  7.867440e+05  03-APR-2024           10
# ...

# %%
capital_market.bhav_copy_with_delivery(trade_date='3-4-2024')
# Out:
#           SYMBOL SERIES  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE  \
# 0     1018GS2026     GS      109.50      111.00     109.50       111.00
# 1      20MICRONS     EQ      152.80      155.80     152.55       154.95
# 2     21STCENMGM     BE       44.05       44.05      44.05        44.05
# 3         360ONE     EQ      695.85      745.45     695.85       721.35
# 4      3IINFOLTD     EQ       43.00       45.00      42.20        44.70
# ...          ...    ...         ...         ...        ...          ...
# 2672        ZOTA     EQ      497.55      510.00     492.60       501.95
# 2673       ZUARI     EQ      192.00      200.25     191.30       198.50
# 2674    ZUARIIND     EQ      333.00      349.00     332.95       346.45
# 2675   ZYDUSLIFE     EQ      997.00      999.50     981.20       987.70
# 2676   ZYDUSWELL     EQ     1502.00     1559.85    1500.00      1550.45
#
#       PREV_CLOSE  TTL_TRD_QNTY  TURNOVER_LACS  NO_OF_TRADES DELIV_QTY  \
# ...

# %%
capital_market.block_deals_data(period='1M')
# Out:
#            Date      Symbol               SecurityName  \
# 0   05-MAR-2024      HATSUN   Hatsun Agro Product Ltd.
# 1   05-MAR-2024      HATSUN   Hatsun Agro Product Ltd.
# 2   06-MAR-2024      DOLLAR  Dollar Industries Limited
# 3   06-MAR-2024      DOLLAR  Dollar Industries Limited
# 4   06-MAR-2024      DOLLAR  Dollar Industries Limited
# ..          ...         ...                        ...
# 66  27-MAR-2024      VIJAYA  Vijaya Diagnostic Cen Ltd
# 67  28-MAR-2024       DHANI     Dhani Services Limited
# 68  28-MAR-2024       DHANI     Dhani Services Limited
# 69  28-MAR-2024  SHRIRAMFIN    Shriram Finance Limited
# 70  28-MAR-2024  SHRIRAMFIN    Shriram Finance Limited
#
#                                      ClientName Buy/Sell QuantityTraded  \
# 0                              CHANDRAMOGAN R G      BUY       1,00,162
# 1                    MALABAR VALUE FUND   - AIF     SELL       1,00,162
# 2                           BAJRANG KUMAR GUPTA     SELL       5,00,000
# ...

# %%
capital_market.bulk_deal_data(period='1M')
# Out:
#              Date    Symbol            SecurityName  \
# 0     04-MAR-2024     ARIES      Aries Agro Limited
# 1     04-MAR-2024     ARIES      Aries Agro Limited
# 2     04-MAR-2024     ARIES      Aries Agro Limited
# 3     04-MAR-2024     ARIES      Aries Agro Limited
# 4     04-MAR-2024     ARIES      Aries Agro Limited
# ...           ...       ...                     ...
# 1307  03-APR-2024  VIKASECO   Vikas EcoTech Limited
# 1308  03-APR-2024      VSTL  Vibhor Steel Tubes Ltd
# 1309  03-APR-2024      VSTL  Vibhor Steel Tubes Ltd
# 1310  03-APR-2024  ZEEMEDIA        Zee News Limited
# 1311  03-APR-2024  ZEEMEDIA        Zee News Limited
#
#                                             ClientName Buy/Sell  \
# 0     CITADEL SECURITIES INDIA MARKETS PRIVATE LIMITED      BUY
# 1     CITADEL SECURITIES INDIA MARKETS PRIVATE LIMITED     SELL
# 2                        CLT RESEARCH TECH PRIVATE LTD      BUY
# 3                        CLT RESEARCH TECH PRIVATE LTD     SELL
# ...

# %%
data=capital_market.price_volume_and_deliverable_position_data(symbol='NHPC',period='1M')
data
# Out:
# c:\Users\kruna\AppData\Local\Programs\Python\Python312\Lib\site-packages\nselib\capital_market\capital_market_data.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
#    Symbol Series         Date PrevClose OpenPrice HighPrice  LowPrice  \
# 0    NHPC     EQ  04-Mar-2024     90.45     91.00     91.45     88.80
# 1    NHPC     N2  04-Mar-2024  1,206.70  1,288.80  1,288.80  1,207.00
# 2    NHPC     N5  04-Mar-2024  1,200.27  1,205.00  1,205.00  1,205.00
# 3    NHPC     EQ  05-Mar-2024     89.10     89.00     93.20     88.20
# 4    NHPC     EQ  06-Mar-2024     92.45     93.60     95.50     90.80
# 5    NHPC     N2  06-Mar-2024  1,207.00  1,207.00  1,207.00  1,207.00
# ...

# %%
data[data['Series']=='EQ']
# Out:
#    Symbol Series         Date PrevClose OpenPrice HighPrice LowPrice  \
# 0    NHPC     EQ  04-Mar-2024     90.45     91.00     91.45    88.80
# 3    NHPC     EQ  05-Mar-2024     89.10     89.00     93.20    88.20
# 4    NHPC     EQ  06-Mar-2024     92.45     93.60     95.50    90.80
# 7    NHPC     EQ  07-Mar-2024     91.50     91.50     91.55    89.75
# 8    NHPC     EQ  11-Mar-2024     90.05     90.60     91.95    89.35
# 11   NHPC     EQ  12-Mar-2024     90.15     89.95     90.45    86.30
# 13   NHPC     EQ  13-Mar-2024     86.65     86.15     86.50    77.35
# 15   NHPC     EQ  14-Mar-2024     78.15     78.55     86.70    73.60
# 16   NHPC     EQ  15-Mar-2024     85.05     85.05     87.80    80.60
# 17   NHPC     EQ  18-Mar-2024     82.95     84.10     85.90    82.00
# 21   NHPC     EQ  19-Mar-2024     82.50     82.50     83.50    81.50
# 23   NHPC     EQ  20-Mar-2024     82.45     83.00     83.75    80.70
# 24   NHPC     EQ  21-Mar-2024     82.85     84.10     85.35    83.40
# ...
